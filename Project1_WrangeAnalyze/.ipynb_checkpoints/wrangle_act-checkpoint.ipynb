# %% [markdown]
# # The WeRateDogs Twitter archive

# %% [markdown]
# ### What we know-
# 1. Some ratings are not correct
# 2. Dog names could be incorrect
# 3. Dog stages are incorrect
# 4. Original ratings and no retweets
# 5. no need to go beyond August 1st, 2017

# %% [markdown]
# ## Gathering
#
#     - Twitter archive
#     - image_predictions
#     - extended tweets data

# %%
# %pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (4.14.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from tweepy) (2.29.0)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->tweepy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/deepaliyadav/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27.0->tweepy) (2023.5.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests as re
import numpy as np
import pandas as pd
import json
import tweepy
import os
from sqlalchemy import create_engine

# %%
df_twitter = pd.read_csv('twitter-archive-enhanced.csv')

# %%
df_twitter.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1553  688908934925697024                    NaN                  NaN
# 1954  673656262056419329                    NaN                  NaN
# 114   870656317836468226                    NaN                  NaN
# 202   853639147608842240                    NaN                  NaN
# 1618  684969860808454144           6.849598e+17         4.196984e+09
# 1644  683852578183077888                    NaN                  NaN
# 2322  666430724426358785                    NaN                  NaN
# 89    875021211251597312                    NaN                  NaN
# 931   754120377874386944                    NaN                  NaN
# 187   856282028240666624                    NaN                  NaN
#
#                       timestamp  \
# 1553  2016-01-18 02:21:04 +0000
# 1954  2015-12-07 00:12:23 +0000
# 114   2017-06-02 15:00:16 +0000
# 202   2017-04-16 16:00:07 +0000
# 1618  2016-01-07 05:28:35 +0000
# 1644  2016-01-04 03:28:54 +0000
# 2322  2015-11-17 01:40:41 +0000
# 89    2017-06-14 16:04:48 +0000
# 931   2016-07-16 01:08:03 +0000
# 187   2017-04-23 23:01:59 +0000
#
#                                                  source  \
# 1553  <a href="http://twitter.com/download/iphone" r...
# 1954  <a href="http://twitter.com/download/iphone" r...
# 114   <a href="http://twitter.com/download/iphone" r...
# 202   <a href="http://twitter.com/download/iphone" r...
# 1618  <a href="http://twitter.com/download/iphone" r...
# 1644  <a href="http://twitter.com/download/iphone" r...
# 2322  <a href="http://twitter.com/download/iphone" r...
# 89    <a href="http://twitter.com/download/iphone" r...
# 931   <a href="http://twitter.com/download/iphone" r...
# 187   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1553  Meet Clarence. He does parkour. 8/10 very tale...                  NaN
# 1954  This is Albert AKA King Banana Peel. He's a ki...                  NaN
# 114   This is Cody. He zoomed too aggressively and t...                  NaN
# 202   A photographer took pictures before and after ...                  NaN
# 1618  For those who claim this is a goat, u are wron...                  NaN
# 1644  Say hello to Tiger. He's a penbroke (little do...                  NaN
# 2322  Oh boy what a pup! Sunglasses take this one to...                  NaN
# 89    Guys please stop sending pictures without any ...                  NaN
# 931   When you hear your owner say they need to hatc...                  NaN
# 187   This is Cermet, Paesh, and Morple. They are ab...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1553                       NaN                        NaN
# 1954                       NaN                        NaN
# 114                        NaN                        NaN
# 202                        NaN                        NaN
# 1618                       NaN                        NaN
# 1644                       NaN                        NaN
# 2322                       NaN                        NaN
# 89                         NaN                        NaN
# 931                        NaN                        NaN
# 187                        NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 1553  https://twitter.com/dog_rates/status/688908934...                 8
# 1954  https://twitter.com/dog_rates/status/673656262...                10
# 114   https://www.gofundme.com/help-fix-codys-torn-a...                13
# 202   https://twitter.com/dog_rates/status/853639147...                13
# 1618                                                NaN                 5
# 1644  https://twitter.com/dog_rates/status/683852578...                10
# 2322  https://twitter.com/dog_rates/status/666430724...                 6
# 89    https://twitter.com/dog_rates/status/875021211...                12
# 931   https://twitter.com/dog_rates/status/754120377...                10
# 187   https://twitter.com/dog_rates/status/856282028...                14
#
#       rating_denominator      name doggo floofer  pupper puppo
# 1553                  10  Clarence  None    None    None  None
# 1954                  10    Albert  None    None  pupper  None
# 114                   10      Cody  None    None    None  None
# 202                   10      None  None    None    None  None
# 1618                  10      None  None    None    None  None
# 1644                  10     Tiger  None    None    None  None
# 2322                  10      None  None    None    None  None
# 89                    10      None  None    None    None  None
# 931                   10      None  None    None    None  None
# 187                   10    Cermet  None    None    None  None

# %%
# Getting the contents of the URL and writing in a file
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
url2 = 'https://video.udacity-data.com/topher/2018/November/5be5fb7d_tweet-json/tweet-json.txt'
file = re.get(url)
file2 = re.get(url2)
with open('image_predictions.tsv', mode='wb') as txt:
    txt.write(file.content)

with open('tweet_json.txt', mode='wb') as txt:
    txt.write(file2.content)

# %%
# Reading the contents of tsv as a dataframe
df_image = pd.read_csv('image_predictions.tsv', sep='\t')

# %%
df_image
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
# Reading the third piece of data line by line
json_data = []
with open('tweet_json.txt', mode='r') as file:
    for line in file:
        json_txt = json.loads(line)
        json_data.append(json_txt)
#     data = file.readline()
#     json_data = json.loads(data)
    
#     print(json_data)

# %%
df_tweets = pd.DataFrame(json_data)

# %%
df_tweets.sample(20)
# Out:
#                           created_at                  id              id_str  \
# 2090  Sun Nov 29 01:52:48 +0000 2015  670782429121134593  670782429121134593
# 99    Thu Jun 08 14:20:41 +0000 2017  872820683541237760  872820683541237760
# 1320  Sun Mar 06 01:31:11 +0000 2016  706291001778950144  706291001778950144
# 1139  Tue May 03 23:42:26 +0000 2016  727644517743104000  727644517743104000
# 1374  Mon Feb 22 16:27:58 +0000 2016  701805642395348998  701805642395348998
# 428   Mon Jan 16 21:32:06 +0000 2017  821107785811234820  821107785811234820
# 634   Tue Nov 01 23:53:02 +0000 2016  793601777308463104  793601777308463104
# 881   Mon Aug 01 23:15:56 +0000 2016  760252756032651264  760252756032651264
# 606   Mon Nov 14 17:03:50 +0000 2016  798209839306514432  798209839306514432
# 1469  Mon Feb 01 03:04:14 +0000 2016  693993230313091072  693993230313091072
# 0     Tue Aug 01 16:23:56 +0000 2017  892420643555336193  892420643555336193
# 2134  Fri Nov 27 01:42:24 +0000 2015  670055038660800512  670055038660800512
# 1057  Sat Jun 11 21:27:17 +0000 2016  741743634094141440  741743634094141440
# 429   Mon Jan 16 17:20:45 +0000 2017  821044531881721856  821044531881721856
# 2258  Fri Nov 20 03:51:47 +0000 2015  667550882905632768  667550882905632768
# 644   Mon Oct 31 19:00:10 +0000 2016  793165685325201412  793165685325201412
# 311   Fri Feb 24 23:04:14 +0000 2017  835264098648616962  835264098648616962
# 2299  Wed Nov 18 18:17:59 +0000 2015  667044094246576128  667044094246576128
# 1496  Wed Jan 27 18:42:06 +0000 2016  692417313023332352  692417313023332352
# 533   Fri Dec 09 06:17:20 +0000 2016  807106840509214720  807106840509214720
#
#                                               full_text  truncated  \
# 2090  This dude slaps your girl's ass what do you do...      False
# 99    Here are my favorite #dogsatpollingstations \n...      False
# 1320  When you're just relaxin and having a swell ti...      False
# 1139  Here's a doggo struggling to cope with the win...      False
# 1374  Please pray for this pupper. Nothing wrong wit...      False
# 428   Here's a doggo who looks like he's about to gi...      False
# 634   This is Dobby. I can't stop looking at her fee...      False
# 881   This is Fido. He can tell the weather. Not goo...      False
# 606   This is Cooper. His bow tie was too heavy for ...      False
# 1469  These lil fellas are the best of friends. 12/1...      False
# 0     This is Phineas. He's a mystical boy. Only eve...      False
# 2134  This is Tommy. He's a cool dog. Hard not to st...      False
# 1057  Meet Aqua. She's a sandy pupper. Not sure how ...      False
# 429   This is Flash. He went way too hard celebratin...      False
# 2258  RT @dogratingrating: Unoriginal idea. Blatant ...      False
# 644   This is Benji. He's Air Bud. It's a low effort...      False
# 311   Meet Lola. Her hobbies include being precious ...      False
# 2299            12/10 gimme now https://t.co/QZAnwgnOMB      False
# 1496  Meet Herschel. He's slightly bigger than ur av...      False
# 533   This is Stephan. He just wants to help. 13/10 ...      False
#
#      display_text_range                                           entities  \
# 2090            [0, 76]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 99             [0, 140]  {'hashtags': [{'text': 'dogsatpollingstations'...
# 1320           [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1139            [0, 55]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1374           [0, 132]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 428            [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 634             [0, 76]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 881            [0, 116]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 606            [0, 106]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1469           [0, 125]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 0               [0, 85]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2134           [0, 130]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1057           [0, 115]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 429            [0, 125]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2258           [0, 104]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 644            [0, 128]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 311            [0, 139]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2299            [0, 39]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1496           [0, 140]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 533             [0, 61]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                       extended_entities  \
# 2090  {'media': [{'id': 670782421437169664, 'id_str'...
# 99    {'media': [{'id': 872820673743376386, 'id_str'...
# 1320  {'media': [{'id': 706290925690097664, 'id_str'...
# 1139  {'media': [{'id': 727644511996776449, 'id_str'...
# 1374                                                NaN
# 428   {'media': [{'id': 821107776281669633, 'id_str'...
# 634   {'media': [{'id': 793601770836660225, 'id_str'...
# 881   {'media': [{'id': 760252748986220544, 'id_str'...
# 606   {'media': [{'id': 798209828535541760, 'id_str'...
# 1469                                                NaN
# 0     {'media': [{'id': 892420639486877696, 'id_str'...
# 2134  {'media': [{'id': 670055031027159040, 'id_str'...
# 1057  {'media': [{'id': 741743615312056320, 'id_str'...
# 429   {'media': [{'id': 821044517277233152, 'id_str'...
# 2258  {'media': [{'id': 667548406944960512, 'id_str'...
# 644   {'media': [{'id': 793165673107161088, 'id_str'...
# 311   {'media': [{'id': 835264086267072512, 'id_str'...
# 2299  {'media': [{'id': 667044086843637761, 'id_str'...
# 1496  {'media': [{'id': 692417305561686016, 'id_str'...
# 533   {'media': [{'id': 807106774843039744, 'id_str'...
#
#                                                  source  \
# 2090  <a href="http://twitter.com/download/iphone" r...
# 99    <a href="http://twitter.com/download/iphone" r...
# 1320  <a href="http://twitter.com/download/iphone" r...
# 1139  <a href="http://twitter.com/download/iphone" r...
# 1374  <a href="http://vine.co" rel="nofollow">Vine -...
# 428   <a href="http://twitter.com/download/iphone" r...
# 634   <a href="http://twitter.com/download/iphone" r...
# 881   <a href="http://twitter.com/download/iphone" r...
# 606   <a href="http://twitter.com/download/iphone" r...
# 1469  <a href="http://vine.co" rel="nofollow">Vine -...
# 0     <a href="http://twitter.com/download/iphone" r...
# 2134  <a href="http://twitter.com/download/iphone" r...
# 1057  <a href="http://twitter.com/download/iphone" r...
# 429   <a href="http://twitter.com/download/iphone" r...
# 2258  <a href="http://twitter.com" rel="nofollow">Tw...
# 644   <a href="http://twitter.com/download/iphone" r...
# 311   <a href="http://twitter.com/download/iphone" r...
# 2299  <a href="http://twitter.com/download/iphone" r...
# 1496  <a href="http://twitter.com/download/iphone" r...
# 533   <a href="http://twitter.com/download/iphone" r...
#
#       in_reply_to_status_id  ... favorite_count  favorited retweeted  \
# 2090                    NaN  ...           1691      False     False
# 99                      NaN  ...          15029      False     False
# 1320                    NaN  ...           1861      False     False
# 1139                    NaN  ...           6431      False     False
# 1374                    NaN  ...           3752      False     False
# 428                     NaN  ...          10645      False     False
# 634                     NaN  ...           8926      False     False
# 881                     NaN  ...           4338      False     False
# 606                     NaN  ...          11548      False     False
# 1469                    NaN  ...           2044      False     False
# 0                       NaN  ...          39467      False     False
# 2134                    NaN  ...            716      False     False
# 1057                    NaN  ...           8945      False     False
# 429                     NaN  ...          14021      False     False
# 2258                    NaN  ...              0      False     False
# 644                     NaN  ...          10478      False     False
# 311                     NaN  ...           8503      False     False
# 2299                    NaN  ...            198      False     False
# 1496                    NaN  ...          10275      False     False
# 533                     NaN  ...         107015      False     False
#
#      possibly_sensitive possibly_sensitive_appealable lang  \
# 2090              False                         False   en
# 99                False                         False   en
# 1320              False                         False   en
# 1139              False                         False   en
# 1374              False                         False   en
# 428               False                         False   en
# 634               False                         False   en
# 881               False                         False   en
# 606               False                         False   en
# 1469              False                         False   en
# 0                 False                         False   en
# 2134              False                         False   en
# 1057              False                         False   en
# 429               False                         False   en
# 2258              False                         False   ro
# 644               False                         False   en
# 311               False                         False   en
# 2299              False                         False   en
# 1496              False                         False   en
# 533               False                         False   en
#
#                                        retweeted_status quoted_status_id  \
# 2090                                                NaN              NaN
# 99                                                  NaN              NaN
# 1320                                                NaN              NaN
# 1139                                                NaN              NaN
# 1374                                                NaN              NaN
# 428                                                 NaN              NaN
# 634                                                 NaN              NaN
# 881                                                 NaN              NaN
# 606                                                 NaN              NaN
# 1469                                                NaN              NaN
# 0                                                   NaN              NaN
# 2134                                                NaN              NaN
# 1057                                                NaN              NaN
# 429                                                 NaN              NaN
# 2258  {'created_at': 'Fri Nov 20 03:41:59 +0000 2015...              NaN
# 644                                                 NaN              NaN
# 311                                                 NaN              NaN
# 2299                                                NaN              NaN
# 1496                                                NaN              NaN
# 533                                                 NaN              NaN
#
#      quoted_status_id_str  quoted_status
# 2090                  NaN            NaN
# 99                    NaN            NaN
# 1320                  NaN            NaN
# 1139                  NaN            NaN
# 1374                  NaN            NaN
# 428                   NaN            NaN
# 634                   NaN            NaN
# 881                   NaN            NaN
# 606                   NaN            NaN
# 1469                  NaN            NaN
# 0                     NaN            NaN
# 2134                  NaN            NaN
# 1057                  NaN            NaN
# 429                   NaN            NaN
# 2258                  NaN            NaN
# 644                   NaN            NaN
# 311                   NaN            NaN
# 2299                  NaN            NaN
# 1496                  NaN            NaN
# 533                   NaN            NaN
#
# [20 rows x 31 columns]

# %%
df_tweets.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'full_text', 'truncated',
#        'display_text_range', 'entities', 'extended_entities', 'source',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'retweet_count', 'favorite_count',
#        'favorited', 'retweeted', 'possibly_sensitive',
#        'possibly_sensitive_appealable', 'lang', 'retweeted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status'],
#       dtype='object')

# %%
# Checking the entities in extended_entities
list(df_tweets[df_tweets['extended_entities'].notnull()].head(1)['extended_entities'].apply(lambda x: x['media'][0].keys()))
# Out:
# [dict_keys(['id', 'id_str', 'indices', 'media_url', 'media_url_https', 'url', 'display_url', 'expanded_url', 'type', 'sizes'])]

# %%
df_tweet = df_tweets[['created_at', 'id', 'retweet_count', 'favorite_count', 'full_text']]

# %%
# media_url from extended_entities
df_tweet['expanded_url'] = df_tweets[df_tweets['extended_entities'].notnull()]['extended_entities'].apply(lambda x: x['media'][0]['expanded_url'])
# Out:
# /tmp/ipykernel_88051/2534768996.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tweet['expanded_url'] = df_tweets[df_tweets['extended_entities'].notnull()]['extended_entities'].apply(lambda x: x['media'][0]['expanded_url'])

# %% [markdown]
# ## Assessing

# %%
df_twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# ### Quality issues
# df_twitter:-
# - 1) tweet_id is int
# - 2) timestamp is object
# - 3) expanded urls has missing data
# - 4) tweet_id with 810984652412424192 doesn't have rating and 666287406224695296 has incorrect i.e. 9/10 instead of 1/2
# - 5) Name for dogs 'None' counted as object
# - 6) Incomplete data for Dog names
# - 7) Incomplete stages for dogs
# - 8) source column can be standardised i.e. iphone, webclient, vine etc
#
#
# df_tweet:-
# - 9) extended_entities colum in df_tweets has media_urls
#
# df_image:-
# - 10) 2075 entries for data(sort missing data)
# - 11) column names for p1 algorithm, p1_conf and p1_dog as user friendly names
#
# ### Tidiness issues
# df_twitter:-
# - 1) Dog stages mentioned as columns
# - 2) dog images and dog stages should be combined
# - 3) Combining the tables into one master dataframe

# %%
df_twitter.sample(20)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 430   821044531881721856                    NaN                  NaN
# 44    883838122936631299                    NaN                  NaN
# 1204  716080869887381504                    NaN                  NaN
# 695   786709082849828864                    NaN                  NaN
# 2098  670727704916926465                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 34    885528943205470208                    NaN                  NaN
# 1143  727314416056803329                    NaN                  NaN
# 105   872122724285648897                    NaN                  NaN
# 1352  703774238772166656                    NaN                  NaN
# 917   756939218950160384                    NaN                  NaN
# 154   862096992088072192                    NaN                  NaN
# 864   762464539388485633                    NaN                  NaN
# 992   748692773788876800                    NaN                  NaN
# 1038  744334592493166593                    NaN                  NaN
# 1015  747103485104099331                    NaN                  NaN
# 1223  714251586676113411                    NaN                  NaN
# 116   870308999962521604                    NaN                  NaN
# 1889  674774481756377088                    NaN                  NaN
# 396   825147591692263424                    NaN                  NaN
#
#                       timestamp  \
# 430   2017-01-16 17:20:45 +0000
# 44    2017-07-09 00:00:04 +0000
# 1204  2016-04-02 01:52:38 +0000
# 695   2016-10-13 23:23:56 +0000
# 2098  2015-11-28 22:15:21 +0000
# 24    2017-07-18 16:08:03 +0000
# 34    2017-07-13 15:58:47 +0000
# 1143  2016-05-03 01:50:44 +0000
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 128  867774946302451713                    NaN                  NaN
#
#                      timestamp  \
# 128  2017-05-25 16:10:44 +0000
#
#                                                 source  \
# 128  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 128  Meet Harold.  He's h*ckin cooperative. 13/10 g...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 128                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 128  https://twitter.com/dog_rates/status/867774946...                13
#
#      rating_denominator    name doggo floofer pupper puppo
# 128                  10  Harold  None    None   None  None

# %% [markdown]
# -----------

# %%
df_image.sample(10)
# Out:
#                 tweet_id                                          jpg_url  \
# 872   697990423684476929  https://pbs.twimg.com/media/Ca_ClYOW0AAsvpE.jpg
# 1583  796865951799083009  https://pbs.twimg.com/media/Cw8JWZ2UsAAJOZ6.jpg
# 1520  787810552592695296  https://pbs.twimg.com/media/Cu7dg2RXYAIaGXE.jpg
# 212   670037189829525505  https://pbs.twimg.com/media/CUxzQ-nWIAAgJUm.jpg
# 1140  729823566028484608  https://pbs.twimg.com/media/CiDap8fWEAAC4iW.jpg
# 1233  746131877086527488  https://pbs.twimg.com/media/ClrK-rGWAAENcAa.jpg
# 1220  743980027717509120  https://pbs.twimg.com/media/ClMl4VLUYAA5qBb.jpg
# 444   674644256330530816  https://pbs.twimg.com/media/CVzRXmXWIAA0Fkr.jpg
# 668   683030066213818368  https://pbs.twimg.com/media/CXqcOHCUQAAugTB.jpg
# 470   675113801096802304  https://pbs.twimg.com/media/CV58a4nXAAApywo.jpg
#
#       img_num            p1   p1_conf  p1_dog                   p2   p2_conf  \
# 872         2      Pembroke  0.984783    True             Cardigan  0.015018
# 1583        1      Cardigan  0.839129    True          Boston_bull  0.080699
# 1520        2           pug  0.362835    True       French_bulldog  0.221864
# 212         1           pot  0.273767   False                 tray  0.092888
# 1140        1        kelpie  0.218408    True        Arabian_camel  0.114368
# 1233        1          chow  0.575637    True           Pomeranian  0.195950
# 1220        1  bull_mastiff  0.975730    True  Rhodesian_ridgeback  0.008073
# 444         1   soccer_ball  0.398102   False               basset  0.335692
# 668         1         boxer  0.722218    True         bull_mastiff  0.193804
# 470         1           bow  0.168020   False                quill  0.108807
#
#       p2_dog                 p3   p3_conf  p3_dog
# 872     True  Shetland_sheepdog  0.000074    True
# 1583    True           Pembroke  0.034505    True
# 1520    True     English_setter  0.080418    True
# 212    False            doormat  0.050728   False
# 1140   False             coyote  0.096409   False
# 1233    True    Norwich_terrier  0.141224    True
# 1220    True                pug  0.005571    True
# 444     True     cocker_spaniel  0.072941    True
# 668     True     French_bulldog  0.055194    True
# 470    False           joystick  0.043312   False

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_image.describe()
# Out:
#            tweet_id      img_num      p1_conf       p2_conf       p3_conf
# count  2.075000e+03  2075.000000  2075.000000  2.075000e+03  2.075000e+03
# mean   7.384514e+17     1.203855     0.594548  1.345886e-01  6.032417e-02
# std    6.785203e+16     0.561875     0.271174  1.006657e-01  5.090593e-02
# min    6.660209e+17     1.000000     0.044333  1.011300e-08  1.740170e-10
# 25%    6.764835e+17     1.000000     0.364412  5.388625e-02  1.622240e-02
# 50%    7.119988e+17     1.000000     0.588230  1.181810e-01  4.944380e-02
# 75%    7.932034e+17     1.000000     0.843855  1.955655e-01  9.180755e-02
# max    8.924206e+17     4.000000     1.000000  4.880140e-01  2.734190e-01

# %%
df_image[df_image['p2_conf'] > 0.4]
# Out:
#                 tweet_id                                          jpg_url  \
# 13    666082916733198337  https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
#
# 1219        1           dalmatian  0.562315    True
# 1386        1             redbone  0.484855    True
# 1418        1              collie  0.503728    True
# 1436        1          Pomeranian  0.554331    True
# 1514        1            Leonberg  0.512034    True
# 1753        1      English_setter  0.526488    True
# 1756        2          Eskimo_dog  0.524454    True
# 1834        1       shopping_cart  0.572422   False
# 1904        1              barrow  0.423150   False
# 2030        1          Eskimo_dog  0.466778    True
# 2037        1                 pug  0.546406    True
# 2065        1            Pembroke  0.511319    True
#
#                               p2   p2_conf  p2_dog  \
# 13                  bull_mastiff  0.404722    True
# 72            Labrador_retriever  0.454937    True
# 101               English_setter  0.451219    True
# 127                     Cardigan  0.425303    True
# 186                 Irish_setter  0.406550    True
# 232                    porcupine  0.460565   False
# 285                        cairn  0.440122    True
# 307                         cock  0.442033   False
# 601                 bull_mastiff  0.420119    True
# 605   Greater_Swiss_Mountain_dog  0.431657    True
# 650             golden_retriever  0.403420    True
# 662                     Cardigan  0.411182    True
# 677                         chow  0.442016    True
# 721                   Eskimo_dog  0.430275    True
# 812                   Eskimo_dog  0.448518    True
# 869                     Shih-Tzu  0.403451    True
# 986                          tub  0.488014   False
# 1036                  coffee_mug  0.418483   False
# 1046                    malamute  0.430624    True
# 1219                  Great_Dane  0.416478    True
# 1386                      beagle  0.437527    True
# 1418               Border_collie  0.450944    True
# 1436                     Samoyed  0.432158    True
# 1514                    keeshond  0.464816    True
# 1753            golden_retriever  0.402815    True
# 1756              Siberian_husky  0.467678    True
# 1834             shopping_basket  0.414002   False
# 1904        Bernese_mountain_dog  0.415374    True
# 2030              Siberian_husky  0.406044    True
# 2037              French_bulldog  0.404291    True
# 2065                    Cardigan  0.451038    True
#
#                                p3   p3_conf  p3_dog
# 13                 French_bulldog  0.048960    True
# 72                         kuvasz  0.024193    True
# 101                    Great_Dane  0.008164    True
# 127                       basenji  0.014753    True
# 186                cocker_spaniel  0.041484    True
# 232                       cardoon  0.008146   False
# 285                 silky_terrier  0.058690    True
# 307                    black_swan  0.001181   False
# 601                French_bulldog  0.009481    True
# 605                   Appenzeller  0.044208    True
# 650                        beagle  0.069486    True
# 662                 Border_collie  0.022412    True
# 677               German_shepherd  0.013206    True
# 721                      malamute  0.118590    True
# 812                    white_wolf  0.041506   False
# 869               Tibetan_terrier  0.039912    True
# 986                     washbasin  0.009298   False
# 1036                          cup  0.088391   False
# 1046               Siberian_husky  0.028454    True
# 1219  German_short-haired_pointer  0.008552    True
# 1386                       basset  0.010585    True
# 1418             English_springer  0.012693    True
# 1436                         chow  0.003199    True
# 1514                   Pomeranian  0.007812    True
# 1753                 Irish_setter  0.034418    True
# 1756                     malamute  0.004976    True
# 1834                   toy_poodle  0.005887    True
# 1904                  EntleBucher  0.067345    True
# 2030                        dingo  0.073414   False
# 2037            Brabancon_griffon  0.044002    True
# 2065                    Chihuahua  0.029248    True

# %%
df_image[(df_image['p1_conf'] < 0.1) & (df_image['p1_dog'] == True) ]
# Out:
#                 tweet_id                                          jpg_url  \
# 2172  https://twitter.com/dog_rates/status/669216679...
# 1060                                                NaN
# 742   https://twitter.com/dog_rates/status/780459368...
# 930   https://twitter.com/dog_rates/status/754011816...
# 1575                                                NaN
# 1351  https://twitter.com/dog_rates/status/703769065...
# 941                                                 NaN
# 219   https://twitter.com/dog_rates/status/850019790...
# 2145  https://twitter.com/dog_rates/status/669753178...
# 1191  https://twitter.com/dog_rates/status/717537687...

# %%
df_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      2354 non-null   object
#  1   id              2354 non-null   int64
#  2   retweet_count   2354 non-null   int64
#  3   favorite_count  2354 non-null   int64
#  4   full_text       2354 non-null   object
#  5   expanded_url    2073 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 110.5+ KB

# %%
df_tweet.describe()
# Out:
#                  id  retweet_count  favorite_count
# count  2.354000e+03    2354.000000     2354.000000
# mean   7.426978e+17    3164.797366     8080.968564
# std    6.852812e+16    5284.770364    11814.771334
# min    6.660209e+17       0.000000        0.000000
# 25%    6.783975e+17     624.500000     1415.000000
# 50%    7.194596e+17    1473.500000     3603.500000
# 75%    7.993058e+17    3652.000000    10122.250000
# max    8.924206e+17   79515.000000   132810.000000

# %%
df_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   created_at      2354 non-null   object
#  1   id              2354 non-null   int64
#  2   retweet_count   2354 non-null   int64
#  3   favorite_count  2354 non-null   int64
#  4   full_text       2354 non-null   object
#  5   expanded_url    2073 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 110.5+ KB

# %% [markdown]
# ## Cleaning

# %%
df_twitter_clean = df_twitter.copy()
df_tweet_clean = df_tweet.copy()
df_image_clean =  df_image.copy()

# %% [markdown]
# ### Define
# 1. df_twitter should have dog stages as a single column
# 2. dog stages are incomplete, extracting the same from text info of the tweet
# 3. dropping unneccesary columns and consolidating the same in a single data frame
#
# ### Code
# 1. using pandas melt to convert stages column of pandas into a single column
# 2. using apply method in pandas to extract dog stages
# 3. using the drop method to remove unwanted columns

# %%
id_vars = ['tweet_id',
 'in_reply_to_status_id',
 'in_reply_to_user_id',
 'timestamp',
 'source',
 'text',
 'retweeted_status_id',
 'retweeted_status_user_id',
 'retweeted_status_timestamp',
 'expanded_urls',
 'rating_numerator',
 'rating_denominator',
 'name',]

# %%
df_twitter_dogs = df_twitter_clean.melt(id_vars=id_vars, value_vars=['doggo', 'floofer', 'pupper', 'puppo'], var_name='stages', value_name='stage_name')

# %%
df_twitter_dogs
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 9419  666049248165822465                    NaN                  NaN
# 9420  666044226329800704                    NaN                  NaN
# 9421  666033412701032449                    NaN                  NaN
# 9422  666029285002620928                    NaN                  NaN
# 9423  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 9419  2015-11-16 00:24:50 +0000
# 9420  2015-11-16 00:04:52 +0000
# 9421  2015-11-15 23:21:54 +0000
# 9422  2015-11-15 23:05:30 +0000
# 9423  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 9419  <a href="http://twitter.com/download/iphone" r...
# 9420  <a href="http://twitter.com/download/iphone" r...
# 9421  <a href="http://twitter.com/download/iphone" r...
# 9422  <a href="http://twitter.com/download/iphone" r...
# 9423  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 9419  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 9420  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 9421  Here is a very happy pup. Big fan of well-main...                  NaN
# 9422  This is a western brown Mitsubishi terrier. Up...                  NaN
# 9423  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 9419                       NaN                        NaN
# 9420                       NaN                        NaN
# 9421                       NaN                        NaN
# 9422                       NaN                        NaN
# 9423                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 9419  https://twitter.com/dog_rates/status/666049248...                 5
# 9420  https://twitter.com/dog_rates/status/666044226...                 6
# 9421  https://twitter.com/dog_rates/status/666033412...                 9
# 9422  https://twitter.com/dog_rates/status/666029285...                 7
# 9423  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name stages stage_name
# 0                     10   Phineas  doggo       None
# 1                     10     Tilly  doggo       None
# 2                     10    Archie  doggo       None
# 3                     10     Darla  doggo       None
# 4                     10  Franklin  doggo       None
# ...                  ...       ...    ...        ...
# 9419                  10      None  puppo       None
# 9420                  10         a  puppo       None
# 9421                  10         a  puppo       None
# 9422                  10         a  puppo       None
# 9423                  10      None  puppo       None
#
# [9424 rows x 15 columns]

# %%
# This order of dog stage fixed the incorrect dog stages in tweets-
# 172     858843525470990336
# 191     855851453814013952
# 200     854010172552949760
# 460     817777686764523521
# 531     808106460588765185
# 565     802265048156610565
# 575     801115127852503040
# 705     785639753186217984
# 733     781308096455073793
# 778     775898661951791106
# 822     770093767776997377
# 889     759793422261743616
# 956     751583847268179968
# 1063    741067306818797568
# 1113    733109485275860992
import numpy as np
def find_stage(text):
    dog_stage = ['pupper', 'floofer', 'puppo', 'doggo']
    for stage in dog_stage:
        if stage in text.lower():
            return stage
    return np.nan

# %%
df_twitter_dogs['stage_refined'] = df_twitter_dogs[df_twitter_dogs['text'].notna()]['text'].apply(find_stage)

# %%
df_twitter_dogs['stage_name'] = df_twitter_dogs['stage_name'].apply(lambda x: np.nan if x == 'None' else x)

# %%
df_twitter_dogs[['stage_name', 'stage_refined']].sample(10)
# Out:
#      stage_name stage_refined
# 7842        NaN       floofer
# 8248        NaN           NaN
# 3075        NaN           NaN
# 6792        NaN           NaN
# 2862        NaN           NaN
# 6361        NaN           NaN
# 7399        NaN         doggo
# 1811        NaN        pupper
# 5260        NaN           NaN
# 2238        NaN           NaN

# %%
df_twitter_dogs[(df_twitter_dogs['stage_name'] != df_twitter_dogs['stage_refined']) & df_twitter_dogs['stage_name'].notna()]['tweet_id']
# Out:
# 172     858843525470990336
# 191     855851453814013952
# 200     854010172552949760
# 460     817777686764523521
# 531     808106460588765185
# 565     802265048156610565
# 575     801115127852503040
# 705     785639753186217984
# 733     781308096455073793
# 778     775898661951791106
# 822     770093767776997377
# 889     759793422261743616
# 956     751583847268179968
# 1063    741067306818797568
# 1113    733109485275860992
# Name: tweet_id, dtype: int64

# %%
df_twitter_dogs = df_twitter_dogs.drop('stages', axis=1);
df_twitter_dogs = df_twitter_dogs.drop('stage_name', axis=1);
df_twitter_dogs = df_twitter_dogs.drop_duplicates()

# %% [markdown]
# ### Test
# Check the row counts and columns

# %%
df_twitter_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  stage_refined               423 non-null    object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 276.1+ KB

# %%
df_twitter_dogs.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name stage_refined
# 0                  10   Phineas           NaN
# 1                  10     Tilly           NaN
# 2                  10    Archie           NaN
# 3                  10     Darla           NaN
# 4                  10  Franklin           NaN

# %% [markdown]
# ### Define
# df_twitter:
# 1) tweet_id should be a string using astype
# 2) timestamp should be an object using to_datetime
#
# ### Code
# use astype method to change the data types
# use to_Datetime to change the timestamp data type
# ### Test

# %%
df_twitter_dogs['tweet_id'] = df_twitter_dogs['tweet_id'].astype(object)

# %%
# removing the timezone information
df_twitter_dogs['timestamp'] = df_twitter_dogs['timestamp'].apply(lambda x: x.split('+')[0].strip())

# %%
df_twitter_dogs['timestamp'] = pd.to_datetime(df_twitter_dogs['timestamp'], format='%Y-%m-%d %H:%M:%S')

# %%
df_twitter_dogs['tweet_id'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2356 entries, 0 to 2355
# Series name: tweet_id
# Non-Null Count  Dtype
# --------------  -----
# 2356 non-null   object
# dtypes: object(1)
# memory usage: 36.8+ KB

# %%
df_twitter_dogs['timestamp'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2356 entries, 0 to 2355
# Series name: timestamp
# Non-Null Count  Dtype
# --------------  -----
# 2356 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 36.8 KB

# %% [markdown]
# ### Define
# df_twitter:
#
# 3) expanded urls has missing data,
# 4) tweet_id with 810984652412424192 doesn't have rating and 666287406224695296 has incorrect i.e. 9/10 instead of 1/2
#
# ### Code
# ### Test

# %%
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 810984652412424192, 'rating_numerator'] = np.nan
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 810984652412424192, 'rating_denominator'] = np.nan
# df_twitter_dogs['tweet_id']

# %%
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 666287406224695296, 'rating_numerator'] = 9
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 666287406224695296, 'rating_denominator'] = 10

# %%
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 810984652412424192, 'rating_numerator']
# Out:
# 516   NaN
# Name: rating_numerator, dtype: float64

# %%
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 810984652412424192, 'rating_denominator']
# Out:
# 516   NaN
# Name: rating_denominator, dtype: float64

# %%
df_twitter_dogs.loc[df_twitter_dogs['tweet_id'] == 666287406224695296, 'rating_numerator']
# Out:
# 2335    9.0
# Name: rating_numerator, dtype: float64

# %% [markdown]
# ### Define
# df_twitter_dogs:
# - 1) source column can be standardised i.e. iphone, webclient, vine etc

# %%
df_twitter_dogs['source'].value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
df_twitter_dogs['source'] = df_twitter_dogs['source'].str.extract(r'>(.*?)<', expand=False).str.strip()

# %%
df_twitter_dogs['source'].sample(5)
# Out:
# 633      Twitter for iPhone
# 2037     Twitter for iPhone
# 1284     Twitter for iPhone
# 1357     Twitter for iPhone
# 1515    Vine - Make a Scene
# Name: source, dtype: object

# %%
source_map = {'iPhone': 'Twitter for iPhone', 'twitter_web_client': 'Twitter Web Client', 'Vine': 'Vine - Make a Scene', 'TweetDeck': 'TweetDeck'}

# %%
def extract_val(value):
    for k,v in source_map.items():
        if v in value:
            return k
    return value

# %%
df_twitter_dogs['source'] = df_twitter_dogs['source'].apply(extract_val)

# %%
df_twitter_dogs['source'].value_counts()
# Out:
# iPhone                2221
# Vine                    91
# twitter_web_client      33
# TweetDeck               11
# Name: source, dtype: int64

# %% [markdown]
# ### Define
# df_twitter_dogs:
# 'name' column has 'None' as names for dogs
# ### Code
# Fix the same with apply method
# ### Test
# display the o/p

# %%
df_twitter_dogs['name'] = df_twitter_dogs['name'].apply(lambda x: np.nan if x == 'None' else x)

# %%
df_twitter_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   object
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   datetime64[ns]
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2355 non-null   float64
#  11  rating_denominator          2355 non-null   float64
#  12  name                        1611 non-null   object
#  13  stage_refined               423 non-null    object
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 276.1+ KB

# %% [markdown]
# ### Define
# - 1) dog images and dog stages should be combined
# - 2) Keeping Tweet Table separate and then later merge for master data
# - 3) Fix the column names for user_friendly names for p1_dog, p1_conf and p1
# - 4) Original ratings with images only
#
# ### Code
# merge the dataframes to later split in different dataframes
# ### Test
# display the o/p

# %%
df_twitter_tweet = df_twitter_dogs.merge(df_tweet_clean, how='left', left_on='tweet_id', right_on='id')

# %%
df_twitter_complete = df_twitter_tweet.merge(df_image_clean, how='left', on='tweet_id')

# %%
list(df_twitter_complete.columns)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'stage_refined',
#  'created_at',
#  'id',
#  'retweet_count',
#  'favorite_count',
#  'full_text',
#  'media_url',
#  'expanded_url',
#  'jpg_url',
#  'img_num',
#  'p1',
#  'p1_conf',
#  'p1_dog',
#  'p2',
#  'p2_conf',
#  'p2_dog',
#  'p3',
#  'p3_conf',
#  'p3_dog']

# %%
list(df_twitter_tweet.columns)
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'retweeted_status_id',
#  'retweeted_status_user_id',
#  'retweeted_status_timestamp',
#  'expanded_urls',
#  'rating_numerator',
#  'rating_denominator',
#  'name',
#  'stage_refined',
#  'created_at',
#  'id',
#  'retweet_count',
#  'favorite_count',
#  'full_text',
#  'media_url',
#  'expanded_url']

# %%
columns_tweets = ['tweet_id',
 'timestamp',
 'source',
 'text',
 'retweet_count',
 'favorite_count',
 'media_url',
 'expanded_url']

columns_dogs = [ 'rating_numerator',
 'rating_denominator',
 'name',
 'stage_refined',
 'tweet_id',
 'jpg_url',
 'img_num',
 'p1',
 'p1_conf',
 'p1_dog',
 'p2',
 'p2_conf',
 'p2_dog',
 'p3',
 'p3_conf',
 'p3_dog'              ]

# %%
df_twitter_master = df_twitter_complete[df_twitter_complete['jpg_url'].notna() & df_twitter_complete['retweeted_status_id'].isna()]

# %%
df_twitter_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    1994 non-null   object
#  1   in_reply_to_status_id       23 non-null     float64
#  2   in_reply_to_user_id         23 non-null     float64
#  3   timestamp                   1994 non-null   datetime64[ns]
#  4   source                      1994 non-null   object
#  5   text                        1994 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               1994 non-null   object
#  10  rating_numerator            1993 non-null   float64
#  11  rating_denominator          1993 non-null   float64
#  12  name                        1448 non-null   object
#  13  stage_refined               342 non-null    object
#  14  created_at                  1994 non-null   object
#  15  id                          1994 non-null   float64
#  16  retweet_count               1994 non-null   float64
#  17  favorite_count              1994 non-null   float64
#  18  full_text                   1994 non-null   object
#  19  media_url                   1994 non-null   object
#  20  expanded_url                1994 non-null   object
#  21  jpg_url                     1994 non-null   object
#  22  img_num                     1994 non-null   float64
#  23  p1                          1994 non-null   object
#  24  p1_conf                     1994 non-null   float64
#  25  p1_dog                      1994 non-null   object
#  26  p2                          1994 non-null   object
#  27  p2_conf                     1994 non-null   float64
#  28  p2_dog                      1994 non-null   object
#  29  p3                          1994 non-null   object
#  30  p3_conf                     1994 non-null   float64
#  31  p3_dog                      1994 non-null   object
# dtypes: datetime64[ns](1), float64(13), object(18)
# memory usage: 514.1+ KB

# %%
df_tweets_data = df_twitter_master[columns_tweets]
df_dogs_data = df_twitter_master[columns_dogs]

# %%
df_dogs_data = df_dogs_data.rename(columns={'p1': 'prediction1', 'p1_conf': 'prediction_percent1', 'p2': 'prediction2', 'p2_conf': 'prediction_percent2', 'p3': 'prediction3', 'p3_conf': 'prediction_percent3' })

# %%
df_dogs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rating_numerator     1993 non-null   float64
#  1   rating_denominator   1993 non-null   float64
#  2   name                 1448 non-null   object
#  3   stage_refined        342 non-null    object
#  4   tweet_id             1994 non-null   object
#  5   jpg_url              1994 non-null   object
#  6   img_num              1994 non-null   float64
#  7   prediction1          1994 non-null   object
#  8   prediction_percent1  1994 non-null   float64
#  9   p1_dog               1994 non-null   object
#  10  prediction2          1994 non-null   object
#  11  prediction_percent2  1994 non-null   float64
#  12  p2_dog               1994 non-null   object
#  13  prediction3          1994 non-null   object
#  14  prediction_percent3  1994 non-null   float64
#  15  p3_dog               1994 non-null   object
# dtypes: float64(6), object(10)
# memory usage: 264.8+ KB

# %%
df_tweets_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1994 entries, 0 to 2355
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        1994 non-null   object
#  1   timestamp       1994 non-null   datetime64[ns]
#  2   source          1994 non-null   object
#  3   text            1994 non-null   object
#  4   retweet_count   1994 non-null   float64
#  5   favorite_count  1994 non-null   float64
#  6   media_url       1994 non-null   object
#  7   expanded_url    1994 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(5)
# memory usage: 140.2+ KB

# %%
df_master = df_tweets_data.merge(df_dogs_data, how='left', on='tweet_id')

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
master_file = 'twitter_archive_master.csv'
df_master.to_csv(master_file, index=False)

# %%
engine = create_engine('sqlite:///twitter_archive.db')

# %%
df_master.to_sql('twitter_master', engine, index=False)
# Out:
# 1994

# %%
df_gather = pd.read_sql('SELECT * FROM twitter_master', engine)

# %%
df_gather
# Out:
#                 tweet_id                   timestamp  source  \
# 0     892420643555336193  2017-08-01 16:23:56.000000  iPhone
# 1     892177421306343426  2017-08-01 00:17:27.000000  iPhone
# 2     891815181378084864  2017-07-31 00:18:03.000000  iPhone
# 3     891689557279858688  2017-07-30 15:58:51.000000  iPhone
# 4     891327558926688256  2017-07-29 16:00:24.000000  iPhone
# ...                  ...                         ...     ...
# 1989  666049248165822465  2015-11-16 00:24:50.000000  iPhone
# 1990  666044226329800704  2015-11-16 00:04:52.000000  iPhone
# 1991  666033412701032449  2015-11-15 23:21:54.000000  iPhone
# 1992  666029285002620928  2015-11-15 23:05:30.000000  iPhone
# 1993  666020888022790149  2015-11-15 22:32:08.000000  iPhone
#
#                                                    text  retweet_count  \
# 0     This is Phineas. He's a mystical boy. Only eve...         8853.0
# 1     This is Tilly. She's just checking pup on you....         6514.0
# 2     This is Archie. He is a rare Norwegian Pouncin...         4328.0
# 3     This is Darla. She commenced a snooze mid meal...         8964.0
# 4     This is Franklin. He would like you to stop ca...         9774.0
# ...                                                 ...            ...
# 1989  Here we have a 1949 1st generation vulpix. Enj...           41.0
# 1990  This is a purebred Piers Morgan. Loves to Netf...          147.0
# 1991  Here is a very happy pup. Big fan of well-main...           47.0
# 1992  This is a western brown Mitsubishi terrier. Up...           48.0
# 1993  Here we have a Japanese Irish Setter. Lost eye...          532.0
#
#       favorite_count                                       media_url  \
# 0            39467.0  http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1            33819.0  http://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2            25461.0  http://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 3            42908.0  http://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 4            41048.0  http://pbs.twimg.com/media/DF6hr6AVYAAZ8G8.jpg
# ...              ...                                             ...
# 1989           111.0  http://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 1990           311.0  http://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 1991           128.0  http://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 1992           132.0  http://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 1993          2535.0  http://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#                                            expanded_url  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...              13.0
# 1     https://twitter.com/dog_rates/status/892177421...              13.0
# 2     https://twitter.com/dog_rates/status/891815181...              12.0
# 3     https://twitter.com/dog_rates/status/891689557...              13.0
# 4     https://twitter.com/dog_rates/status/891327558...              12.0
# ...                                                 ...               ...
# 1989  https://twitter.com/dog_rates/status/666049248...               5.0
# 1990  https://twitter.com/dog_rates/status/666044226...               6.0
# 1991  https://twitter.com/dog_rates/status/666033412...               9.0
# 1992  https://twitter.com/dog_rates/status/666029285...               7.0
# 1993  https://twitter.com/dog_rates/status/666020888...               8.0
#
#       rating_denominator  ... img_num             prediction1  \
# 0                   10.0  ...     1.0                  orange
# 1                   10.0  ...     1.0               Chihuahua
# 2                   10.0  ...     1.0               Chihuahua
# 3                   10.0  ...     1.0             paper_towel
# 4                   10.0  ...     2.0                  basset
# ...                  ...  ...     ...                     ...
# 1989                10.0  ...     1.0      miniature_pinscher
# 1990                10.0  ...     1.0     Rhodesian_ridgeback
# 1991                10.0  ...     1.0         German_shepherd
# 1992                10.0  ...     1.0                 redbone
# 1993                10.0  ...     1.0  Welsh_springer_spaniel
#
#      prediction_percent1  p1_dog         prediction2  prediction_percent2  \
# 0               0.097049       0               bagel             0.085851
# 1               0.323581       1            Pekinese             0.090647
# 2               0.716012       1            malamute             0.078253
# 3               0.170278       0  Labrador_retriever             0.168086
# 4               0.555712       1    English_springer             0.225770
# ...                  ...     ...                 ...                  ...
# 1989            0.560311       1          Rottweiler             0.243682
# 1990            0.408143       1             redbone             0.360687
# 1991            0.596461       1            malinois             0.138584
# 1992            0.506826       1  miniature_pinscher             0.074192
# 1993            0.465074       1              collie             0.156665
#
#       p2_dog                  prediction3  prediction_percent3  p3_dog
# 0          0                       banana             0.076110       0
# 1          1                     papillon             0.068957       1
# 2          1                       kelpie             0.031379       1
# 3          1                      spatula             0.040836       0
# 4          1  German_short-haired_pointer             0.175219       1
# ...      ...                          ...                  ...     ...
# 1989       1                     Doberman             0.154629       1
# 1990       1           miniature_pinscher             0.222752       1
# 1991       1                   bloodhound             0.116197       1
# 1992       1          Rhodesian_ridgeback             0.072010       1
# 1993       1            Shetland_sheepdog             0.061428       1
#
# [1994 rows x 23 columns]

# %% [markdown]
# ### Insight 1
# Most favourited dog

# %%
pd.read_sql('SELECT * FROM twitter_master order by favorite_count desc limit 3', engine)
# Out:
#              tweet_id                   timestamp  source  \
# 0  822872901745569793  2017-01-21 18:26:02.000000  iPhone
# 1  744234799360020481  2016-06-18 18:26:18.000000  iPhone
# 2  879415818425184262  2017-06-26 19:07:24.000000  iPhone
#
#                                                 text  retweet_count  \
# 0  Here's a super supportive puppo participating ...        48265.0
# 1  Here's a doggo realizing you can stand in a po...        79515.0
# 2  This is Duddles. He did an attempt. 13/10 some...        45849.0
#
#    favorite_count                                          media_url  \
# 0        132810.0     http://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg
# 1        131075.0  http://pbs.twimg.com/ext_tw_video_thumb/744234...
# 2        107956.0  http://pbs.twimg.com/ext_tw_video_thumb/879415...
#
#                                         expanded_url  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/822872901...              13.0
# 1  https://twitter.com/dog_rates/status/744234799...              13.0
# 2  https://twitter.com/dog_rates/status/879415818...              13.0
#
#    rating_denominator  ... img_num         prediction1 prediction_percent1  \
# 0                10.0  ...     1.0    Lakeland_terrier            0.196015
# 1                10.0  ...     1.0  Labrador_retriever            0.825333
# 2                10.0  ...     1.0    English_springer            0.383404
#
#    p1_dog         prediction2  prediction_percent2  p2_dog    prediction3  \
# 0       1  Labrador_retriever             0.160329       1  Irish_terrier
# 1       1            ice_bear             0.044681       0        whippet
# 2       1         Boston_bull             0.134967       1       Cardigan
#
#    prediction_percent3  p3_dog
# 0             0.069126       1
# 1             0.018442       1
# 2             0.110481       1
#
# [3 rows x 23 columns]

# %% [markdown]
# ### Insight 2
# Most retweeted dog

# %%
pd.read_sql('SELECT * FROM twitter_master order by retweet_count desc limit 3', engine)
# Out:
#              tweet_id                   timestamp  source  \
# 0  744234799360020481  2016-06-18 18:26:18.000000  iPhone
# 1  807106840509214720  2016-12-09 06:17:20.000000  iPhone
# 2  739238157791694849  2016-06-04 23:31:25.000000  iPhone
#
#                                                 text  retweet_count  \
# 0  Here's a doggo realizing you can stand in a po...        79515.0
# 1  This is Stephan. He just wants to help. 13/10 ...        56625.0
# 2  Here's a doggo blowing bubbles. It's downright...        52360.0
#
#    favorite_count                                          media_url  \
# 0        131075.0  http://pbs.twimg.com/ext_tw_video_thumb/744234...
# 1        107015.0  http://pbs.twimg.com/ext_tw_video_thumb/807106...
# 2         75163.0  http://pbs.twimg.com/ext_tw_video_thumb/739238...
#
#                                         expanded_url  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/744234799...              13.0
# 1  https://twitter.com/dog_rates/status/807106840...              13.0
# 2  https://twitter.com/dog_rates/status/739238157...              13.0
#
#    rating_denominator  ... img_num         prediction1 prediction_percent1  \
# 0                10.0  ...     1.0  Labrador_retriever            0.825333
# 1                10.0  ...     1.0           Chihuahua            0.505370
# 2                10.0  ...     1.0          Eskimo_dog            0.503372
#
#    p1_dog     prediction2  prediction_percent2  p2_dog  prediction3  \
# 0       1        ice_bear             0.044681       0      whippet
# 1       1      Pomeranian             0.120358       1  toy_terrier
# 2       1  Siberian_husky             0.390413       1     malamute
#
#    prediction_percent3  p3_dog
# 0             0.018442       1
# 1             0.077008       1
# 2             0.080901       1
#
# [3 rows x 23 columns]

# %% [markdown]
# ### Insight 3
# Most adopted breed of dogs

# %%
pd.read_sql('SELECT count(*) as count, prediction1 FROM twitter_master group by prediction1 order by count desc limit 5', engine)
# Out:
#    count         prediction1
# 0    139    golden_retriever
# 1     95  Labrador_retriever
# 2     88            Pembroke
# 3     79           Chihuahua
# 4     54                 pug

# %% [markdown]
# ### Insight 4
# prediction of dogs as per stages

# %%
pd.read_sql("SELECT count(*) as count, stage_refined,prediction1 FROM twitter_master where stage_refined != 'None' group by stage_refined order by count desc limit 5", engine)
# Out:
#    count stage_refined     prediction1
# 0    237        pupper  French_bulldog
# 1     68         doggo        Pembroke
# 2     29         puppo        Pembroke
# 3      8       floofer            chow

# %%
df_master['prediction1'].value_counts().head(20).plot(kind='bar', xlabel='Breed', ylabel='Count')
# Out:
# <Axes: xlabel='Breed', ylabel='Count'>

# %%
df_master['stage_refined'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: >
